# %% [markdown]
# # **Correction des surfaces ventilées par usage**
#
# Il y a de nombreuses incohérences dans les surfaces, notamment en relation avec les surfaces de Parkings dont la définition est confuse. 60 % environ des échantillons sont incohérents en raison de divergences dans les sommes de contrôle.
#
# L'objet de cette section est :
# 1. d'identifier les individus qui posent problème (12 classes de problèmes),
# 2. de mieux comprendre la nature des erreurs,
# 3. d'en corriger la plus grande partie possible,
# 4. d'identifier les cas aberrants pour les éliminer du jeu de données pour la modélisation.

# %% [markdown]
# # Reste à faire
#
# stratégie pour les surfaces :
# * repartir du tableau qui met les sous-surfaces en 69 + 1 colonnes
# * pour chaque propriété qui a un parking (cf. num_bivar_analysis) :
#     * Parking not in detailed uses s > 0, s_2 = 0 (146) => l'y ajouter
#         * Attention, cas tordus comme pour 655 : tot. 117950, ext. 11210, int. 106740, usage 1 multifamily : 117950
#         * Dans ce cas, il faut également retrancher 11210 à multifamily
#         * En d'autres termes, il faut coupler cette analyse-réparation avec celle de la surface tot. vs. somme détails
#     * Parking is under accounted s > s_2 > 0 (144) : là il faut corriger soit s, soit s_2 : idem s vs sum(s-details)
#     * Parking is over accounted s_2 > s > 0 (72) : idem
#     * => tout cela serait plus simple en GSheet, mais la mise à plat en 69 + 1 cols est délicate dans cet env.
#     * => En revanche, ce que je peux tout à faire, c'est de l'exporter vers la GSheet
#     * => NB > cette vérification n'est pas faite dans num_bivar mais ??? => mettre un renvoi dans num_bivar
#     * MAIS commencer par terminer mon onglet outliers dans GSheet
#
#
# **NB** > zoomer sur chaque cas avant de trop orienter les traitements.
#
# **Raffiner** : les appartenances aux classes en utilisant des critères statistiques : si déviation par rapport à la classe 1, pouvoir la quantifier. Une déviation mineure n'a pas le même impact qu'une déviation majeure.
#
# **Tableau markdown** Le produire à l'aide d'une fonction (toute bête)

# %% [markdown]
# # Rappel de la problématique
#
# Surface / sa ventilation par usage : voir `num_bivar.analysis.ipynb`
#
# Nous avons validé que la relation `'PropertyGFATotal' = 'PropertyGFAParking' + 'PropertyGFABuilding(s)'` ($a = a_i + a_o$) était parfaitement satisfaite par l'ensemble des individus.
#
# **Q** - *La surface totale est-elle systématiquement la sommes des surfaces par usage ?*
#
# **NB** - le cas du parking est spécial : il faut vérifier qu'il y a cohérence entre la surface indiquée dans `'PropertyGFAParking'` et celle indiquée dans l'éventuel des 3 usages ventilés ayant pour label `'Parking'`.
#
# Bilan :
# * Pas d'exclusion
# * 72 % d'individus vérifient la relation (erreur tolérée 1 pour 1000).
# * 28 % ne la vérifient pas ... <mark>Analyse à poursuivre en réutilisant l'histogramme pentes</mark>
# * Pour les 593 propriétés avec parking, les inconsistances dépassent les consistances.. quelque chose ne va pas.
#
# Formalisation et méthode :
#
# Voir `multi_index_demo.ipynb` pour la définition de toutes les variables formelles.
#
# Ici, nous utilisons ce sous-ensemble :
# * $U=\{u_k, k=0, ...\}$ ⚪ `'u_0', ...` ⚪ Ensemble des labels d'usages, ordonnés par surface totale décroissante.
# * $A_U = \{a_{u_k}|u_k \in U\}$ ⚪ `'a_u_0', ...` ⚪ Part de surface dédiée à chaque usage.
# * $a_u$ ⚪ `'a_u'` ⚪ $a_u = \displaystyle\sum_{u_k \in U}{a_{u_k}}$
# * $a_o$ ⚪`'a_o'` ⚪ `'PropertyGFAParking'`
# * $a_i$ ⚪ `'a_i'` ⚪ `'PropertyGFABuilding(s)'`
# * $a$ ⚪ `'a'` ⚪ `'PropertyGFATotal'` ⚪ $a = a_i + a_o$
# * $u_{\text{1st}}, u_{\text{2nd}}, u_{\text{3rd}}$ ⚪ `'u_1st', u_2nd, u_3rd` ⚪ `'LargestPropertyUseType'`, etc
# * $a_{\text{1st}}, a_{\text{2nd}}, a_{\text{3rd}}$ ⚪ `'a_1st', a_2nd, a_3rd` ⚪ `'LargestPropertyUseTypeGFA'`, etc
#
# Les utilitaires clés :
# * `use_types_analysis.use_table` :
#     - elle dérive la table $A_U$ de $a_{\text{1st}}, a_{\text{2nd}}, a_{\text{3rd}}$
#     - en complément, elle produit ces vecteurs analytiques :
#         - $a_u = a_{\text{1st}} + a_{\text{2nd}} + a_{\text{3rd}}$ ⚪ `'a_u'`
#         - $\Delta a = a - a_u$ ⚪ `'a - a_u'`
#         - $a_{u_o}$ ⚪ `'a_u_o'` ⚪ La surface de Parking telle que renseignée dans l'un de $a_{\text{1st}}, a_{\text{2nd}}, a_{\text{3rd}}$
#         - $\Delta a_o = a_o - a_{u_o}$ ⚪ `'a_o - a_u_o'`
#         - $a_{u_i} = a_u - a_{u_o}$ ⚪ `'a_u_i'` ⚪ La somme des surfaces ventilées autres que l'éventuelle surface de Parking
#         - $\Delta a_i = a_i - a_{u_i}$ ⚪ `'a_i - a_u_i'`
#
# La méthode de détection des anomalies et les mesures pour les traiter :

# %% [markdown]
# # Chargement des données

# %%
import numpy as np
def join_use_allocation(subset, data):
    main_uses = data.loc[subset.index, 'ListOfAllPropertyUseTypes':'ThirdLargestPropertyUseTypeGFA']
    main_uses.LargestPropertyUseTypeGFA = main_uses.LargestPropertyUseTypeGFA.astype(np.float64)
    main_uses.SecondLargestPropertyUseTypeGFA = main_uses.SecondLargestPropertyUseTypeGFA.astype(np.float64)
    main_uses.ThirdLargestPropertyUseTypeGFA = main_uses.ThirdLargestPropertyUseTypeGFA.astype(np.float64)
    return subset.join(main_uses, how='left') # .fillna('_')

# %%
from pepper_commons import get_data
from seattle_commons import clean_dataset
import pandas as pd

data = get_data()
_data, not_compliant, outliers = clean_dataset(data)

# données de base
d = _data[['BuildingType', 'PrimaryPropertyType', 'PropertyGFATotal',
    'PropertyGFAParking', 'PropertyGFABuilding(s)']].copy()
d.columns = ['btype', 'ptype', 'a', 'a_o', 'a_i']

# données dérivées de la ventilation des surfaces
from use_types_analysis import use_table_2
use_table, a_u, a_diff, a_u_o, a_o_diff, a_u_i, a_i_diff = use_table_2(_data)

table = pd.concat([d, a_u, a_u_o, a_u_i, a_diff, a_o_diff, a_i_diff, use_table], axis=1)
_table = table[table.columns[:11]]
display(_table)

# Sdiff (Unknown verif calc) = S - SUM(Su)
# Spdiffx : Sext - Sup
# Meilleure conception  : use_table sans Unkown => on le fait ici
# changer les noms de cols pour u1, u2, etc ? à voir..

# algo (une fois table assemblée)
# 1. retirer tout ce qui est ok (1503 cas)
# 2. diviser ce qui est ko en classes cf.nature pb (982 diff > 0, 726 diff < 0)
# 3. représentation graphique du pb
# 4. corriger le pb et montrer graphiquement qu'il l'est
# Out:
# ✔ _data loaded
# ✔ struct loaded
#                     btype               ptype       a     a_o     a_i     a_u  \
# id
# 1          NonResidential               Hotel   88434       0   88434   88434
# 2          NonResidential               Hotel  103566   15064   88502  103566
# 3          NonResidential               Hotel  956110  196718  759392  756493
# 5          NonResidential               Hotel   61320       0   61320   61320
# 8          NonResidential               Hotel  175580   62000  113580  191454
# ...                   ...                 ...     ...     ...     ...     ...
# 50221  Nonresidential COS               Other   18261       0   18261   18261
# 50223  Nonresidential COS               Other   16000       0   16000   16000
# 50224  Nonresidential COS               Other   13157       0   13157   13157
# 50225  Nonresidential COS  Mixed Use Property   14101       0   14101   13586
# 50226  Nonresidential COS  Mixed Use Property   18258       0   18258   17379
#
#        a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i
# id
# 1          0   88434        0            0            0
# 2      15064   88502        0            0            0
# 3          0  756493   199617       196718         2899
# 5          0   61320        0            0            0
# 8      68009  123445   -15874        -6009        -9865
# ...      ...     ...      ...          ...          ...
# 50221      0   18261        0            0            0
# 50223      0   16000        0            0            0
# 50224      0   13157        0            0            0
# 50225      0   13586      515            0          515
# 50226      0   17379      879            0          879
#
# [3211 rows x 11 columns]

# %% [markdown]
# # Les classes de cas
#
# Les cas particuliers sont nombreux ce qui complique cette opération.
#
# Commençons par isoler les classes de cas suivant des critères formels.
#
# Partons de la propriété qui résulte des définitions et de l'identité vérifiée : $\Delta a = \Delta a_i + \Delta a_o$ (A)
#
# Suivant les cas $\Delta x = 0, \gt 0, \lt 0$, avec $x=a, a_i,  a_o$, on peut isoler en principe $3^3 = 27$ cas.
#
# Mais la relation (A) entraîne qu'il n'y a que 13 cas possibles, puisque les 14 autres ne la satisfont pas.
#
# Le tableau suivant définit les classes correspondant à ces cas :
#
# |Classe|$\Delta a$|$\Delta a_i$|$\Delta a_o$|#|%|Commentaire/correction|
# |-|-|-|-|-|-|-|
# |0|= 0|= 0|= 0|1278|**40**|✔ Tout est ok|
# |1|= 0|> 0|< 0|182|6|Transfert $a_{u_i} \rightarrow a_{u_o}$|
# |2|= 0|< 0|> 0|43|1|Transfert $a_{u_o} \rightarrow a_{u_i}$|
# |3|> 0|= 0|> 0|23|1|Enregistrement $a_{u_e}$|
# |4|> 0|> 0|= 0|621|**19**|Enregistrement $a_{u_i}$|
# |5|> 0|> 0|> 0|96|3|Enregistrement $a_{u_i}$ et $a_{u_o}$|
# |6|> 0|> 0|< 0|179|6||
# |7|> 0|< 0|> 0|63|2||
# |8|< 0|= 0|< 0|117|4||
# |9|< 0|> 0|< 0|107|3||
# |10|< 0|< 0|= 0|355|**11**||
# |12|< 0|< 0|> 0|67|2||
# |12|< 0|< 0|< 0|80|2||

# %%
a_eq_a_u = _table['a - a_u'] == 0
a_lt_a_u = _table['a - a_u'] < 0
a_gt_a_u = _table['a - a_u'] > 0
a_neq_a_u = ~a_eq_a_u

a_i_eq_a_u_i = _table['a_i - a_u_i'] == 0
a_i_lt_a_u_i = _table['a_i - a_u_i'] < 0
a_i_gt_a_u_i = _table['a_i - a_u_i'] > 0
a_i_neq_a_u_i = ~a_i_eq_a_u_i

a_o_eq_a_u_o = _table['a_o - a_u_o'] == 0
a_o_lt_a_u_o = _table['a_o - a_u_o'] < 0
a_o_gt_a_u_o = _table['a_o - a_u_o'] > 0
a_o_neq_a_u_o = ~a_o_eq_a_u_o

a_class = [
    a_eq_a_u & a_i_eq_a_u_i,
    a_eq_a_u & a_i_gt_a_u_i,
    a_eq_a_u & a_i_lt_a_u_i,

    a_gt_a_u & a_i_eq_a_u_i & a_o_gt_a_u_o,
    a_gt_a_u & a_i_gt_a_u_i & a_o_eq_a_u_o,
    a_gt_a_u & a_i_gt_a_u_i & a_o_gt_a_u_o,
    a_gt_a_u & a_i_gt_a_u_i & a_o_lt_a_u_o,
    a_gt_a_u & a_i_lt_a_u_i & a_o_gt_a_u_o,

    a_lt_a_u & a_i_eq_a_u_i & a_o_lt_a_u_o,
    a_lt_a_u & a_i_gt_a_u_i & a_o_lt_a_u_o,
    a_lt_a_u & a_i_lt_a_u_i & a_o_eq_a_u_o,
    a_lt_a_u & a_i_lt_a_u_i & a_o_gt_a_u_o,
    a_lt_a_u & a_i_lt_a_u_i & a_o_lt_a_u_o
]

# %% [markdown]
# # $\Delta a = 0 \Leftrightarrow a = a_u$<br/>Classes 0 à 2<br/>1503 cas, 47 % des cas

# %%
nil_a_diff = _table[a_eq_a_u]
display(nil_a_diff)
# Out:
#                     btype  ptype       a    a_o     a_i     a_u  a_u_o  \
# id
# 1          NonResidential  Hotel   88434      0   88434   88434      0
# 2          NonResidential  Hotel  103566  15064   88502  103566  15064
# 5          NonResidential  Hotel   61320      0   61320   61320      0
# 11         NonResidential  Other  102761      0  102761  102761      0
# 12         NonResidential  Hotel  163984      0  163984  163984      0
# ...                   ...    ...     ...    ...     ...     ...    ...
# 50208  Nonresidential COS  Other   12769      0   12769   12769      0
# 50212  Nonresidential COS  Other   23445      0   23445   23445      0
# 50221  Nonresidential COS  Other   18261      0   18261   18261      0
# 50223  Nonresidential COS  Other   16000      0   16000   16000      0
# 50224  Nonresidential COS  Other   13157      0   13157   13157      0
#
#         a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i
# id
# 1       88434        0            0            0
# 2       88502        0            0            0
# 5       61320        0            0            0
# 11     102761        0            0            0
# 12     163984        0            0            0
# ...       ...      ...          ...          ...
# 50208   12769        0            0            0
# 50212   23445        0            0            0
# 50221   18261        0            0            0
# 50223   16000        0            0            0
# 50224   13157        0            0            0
#
# [1503 rows x 11 columns]

# %% [markdown]
# ## Cas valides (classe 0)<br/>1278 cas, 40 % des cas
#
# Ce sont les cas où :
# * $\Delta a = 0$
# * $\Delta a_i = 0$
# * $\Delta a_o = 0$

# %%
class_0_members = _table[a_class[0]]
display(class_0_members)
# Out:
#                     btype  ptype       a    a_o     a_i     a_u  a_u_o  \
# id
# 1          NonResidential  Hotel   88434      0   88434   88434      0
# 2          NonResidential  Hotel  103566  15064   88502  103566  15064
# 5          NonResidential  Hotel   61320      0   61320   61320      0
# 11         NonResidential  Other  102761      0  102761  102761      0
# 12         NonResidential  Hotel  163984      0  163984  163984      0
# ...                   ...    ...     ...    ...     ...     ...    ...
# 50208  Nonresidential COS  Other   12769      0   12769   12769      0
# 50212  Nonresidential COS  Other   23445      0   23445   23445      0
# 50221  Nonresidential COS  Other   18261      0   18261   18261      0
# 50223  Nonresidential COS  Other   16000      0   16000   16000      0
# 50224  Nonresidential COS  Other   13157      0   13157   13157      0
#
#         a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i
# id
# 1       88434        0            0            0
# 2       88502        0            0            0
# 5       61320        0            0            0
# 11     102761        0            0            0
# 12     163984        0            0            0
# ...       ...      ...          ...          ...
# 50208   12769        0            0            0
# 50212   23445        0            0            0
# 50221   18261        0            0            0
# 50223   16000        0            0            0
# 50224   13157        0            0            0
#
# [1278 rows x 11 columns]

# %% [markdown]
# ## Incohérences de classe 1<br/>182 cas, 6 % des cas
#
# Ce sont  les cas où :
# * $\Delta a = 0$
# * $\Delta a_i \gt 0$
# * $\Delta a_o \lt 0$
#
# Cela signifie que si la surface totale et la somme de ses surfaces par usage coïncident, la quantité de surface de Parking renseignée dans `'PropertyGFAParking'` diffère de celle qui apparaît dans l'un des 3 `'LargestPropertyUseTypeGFA'`, etc
#
# Le traitement consiste à rectifier la ventilation et éventuellement `'ListOfAllPropertyUseTypes'`.
#
# Dans tous les cas, nous fixons $a, a_i, a_o$ comme référence et corrigeons les $a_{u_k}$ pour les mettre en cohérence.
#
# Plusieurs cas sont à distinguer selon que :
# * la surface de Parking fait partie de la ventilation ou non ($a_{u_o} = 0$).
# * les 3 places de ventilation sont déjà prises ou non ($n_u = 3$).
# * il n'y a pas de surface par usage autre que Parking ($a_{u_i} = 0$).
#
# Les traitements :
# * si la surface de Parking fait partie de la ventilation : ajout de la quantité $\Delta a_e$ à cette surface, et :
#     - si $n_u > 1$ (équivalent à ($a_{u_i} \ne 0$)) retrait de la même quantité en fractions égales des autres usages (1 ou 2),
#     - si $n_u = 1$ (équivalent à ($a_{u_i} = 0$)), ajout de l'usage ? `'Others'` et retrait : problème, cela conduit à une surface négative.
# * si la surface de Parking ne fait pas partie de la ventilation ($a_{u_o} = 0$) :
#     - .. compliqué .. à reprendre sur un prochain sprint, pas sur celui-ci de réactivation
#
# ..

# %%
class_1_members = _table[a_class[1]]
display(join_use_allocation(class_1_members, data))
# Out:
#                       btype                  ptype       a  a_o     a_i  \
# id
# 423          NonResidential           Large Office  794592    0  794592
# 691    Multifamily HR (10+)  High-Rise Multifamily   99470    0   99470
# 738          NonResidential                  Other  143439    0  143439
# 19453  Multifamily LR (1-4)   Low-Rise Multifamily   76285    0   76285
# 19454  Multifamily LR (1-4)   Low-Rise Multifamily   46873    0   46873
# ...                     ...                    ...     ...  ...     ...
# 49870  Multifamily MR (5-9)   Mid-Rise Multifamily   55113    0   55113
# 49874  Multifamily LR (1-4)   Low-Rise Multifamily   93179    0   93179
# 49994  Multifamily HR (10+)  High-Rise Multifamily  269065    0  269065
# 50011  Multifamily MR (5-9)   Mid-Rise Multifamily   85647    0   85647
# 50047  Multifamily MR (5-9)   Mid-Rise Multifamily  318835    0  318835
#
#           a_u  a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 423    794592  36606  757986        0       -36606        36606
# 691     99470  11000   88470        0       -11000        11000
# 738    143439  23869  119570        0       -23869        23869
# 19453   76285  15798   60487        0       -15798        15798
# 19454   46873  16959   29914        0       -16959        16959
# ...       ...    ...     ...      ...          ...          ...
# 49870   55113  13049   42064        0       -13049        13049
# 49874   93179  29516   63663        0       -29516        29516
# 49994  269065  75138  193927        0       -75138        75138
# 50011   85647  13119   72528        0       -13119        13119
# 50047  318835  82608  236227        0       -82608        82608
#
#                         ListOfAllPropertyUseTypes LargestPropertyUseType  \
# id
# 423                        Office, Other, Parking                 Office
# 691    Multifamily Housing, Parking, Retail Store    Multifamily Housing
# 738                                Other, Parking                  Other
# 19453                Multifamily Housing, Parking    Multifamily Housing
# 19454                Multifamily Housing, Parking    Multifamily Housing
# ...                                           ...                    ...
# 49870                Multifamily Housing, Parking    Multifamily Housing
# 49874                Multifamily Housing, Parking    Multifamily Housing
# 49994                Multifamily Housing, Parking    Multifamily Housing
# 50011                Multifamily Housing, Parking    Multifamily Housing
# 50047                Multifamily Housing, Parking    Multifamily Housing
#
#        LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# id
# 423                     748011.0                      Parking
# 691                      79470.0                      Parking
# 738                     119570.0                      Parking
# 19453                    60487.0                      Parking
# 19454                    29914.0                      Parking
# ...                          ...                          ...
# 49870                    42064.0                      Parking
# 49874                    63663.0                      Parking
# 49994                   193927.0                      Parking
# 50011                    72528.0                      Parking
# 50047                   236227.0                      Parking
#
#        SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# id
# 423                            36606.0                       Other
# 691                            11000.0                Retail Store
# 738                            23869.0                         NaN
# 19453                          15798.0                         NaN
# 19454                          16959.0                         NaN
# ...                                ...                         ...
# 49870                          13049.0                         NaN
# 49874                          29516.0                         NaN
# 49994                          75138.0                         NaN
# 50011                          13119.0                         NaN
# 50047                          82608.0                         NaN
#
#        ThirdLargestPropertyUseTypeGFA
# id
# 423                            9975.0
# 691                            9000.0
# 738                               NaN
# 19453                             NaN
# 19454                             NaN
# ...                               ...
# 49870                             NaN
# 49874                             NaN
# 49994                             NaN
# 50011                             NaN
# 50047                             NaN
#
# [182 rows x 18 columns]

# %% [markdown]
# ## Incohérences de classe 2<br/>43 cas, 1 % des cas
#
# Ce sont  les cas où :
# * $\Delta a = 0$
# * $\Delta a_i \lt 0$
# * $\Delta a_o \gt 0$

# %%
class_2_members = _table[a_class[2]]
class_2_members_details = join_use_allocation(class_2_members, data)
print(class_2_members_details.shape[0])
display(class_2_members_details)
# Out:
# 43
#                       btype                        ptype        a     a_o  \
# id
# 70           NonResidential                        Hotel   155602   36744
# 114          NonResidential                 Large Office   920598  303707
# 245          NonResidential                        Other  1585960  327680
# 322          NonResidential                 Large Office   100734   26731
# 375          NonResidential                 Large Office   396626  124216
# 410          NonResidential                        Hotel   332067   59280
# 434          NonResidential                        Other   206950   97400
# 441          NonResidential                        Hotel   109017   29409
# 521          NonResidential  Small- and Mid-Sized Office    90000   36528
# 549          NonResidential  Small- and Mid-Sized Office    78672   28427
# 551          NonResidential           Mixed Use Property    75844   19928
# 565          NonResidential                 Large Office   102290   42440
# 650          NonResidential  Small- and Mid-Sized Office    91706   36583
# 655    Multifamily MR (5-9)         Mid-Rise Multifamily   117950   11210
# 740          NonResidential  Small- and Mid-Sized Office    77174   25800
# 809          NonResidential  Small- and Mid-Sized Office    95760   15840
# 837          NonResidential                    Warehouse    87332    6458
# 19690  Multifamily MR (5-9)         Mid-Rise Multifamily    88144    3102
# 20082        NonResidential                        Hotel    61180   12960
# 20398        NonResidential                        Other    39320    6960
# 21178        NonResidential  Small- and Mid-Sized Office    26419    6922
# 21313        NonResidential             Worship Facility    75058   34510
# 21398        NonResidential  Small- and Mid-Sized Office    28380   12180
# 21565  Multifamily LR (1-4)         Low-Rise Multifamily    51510   11878
# 21852  Multifamily LR (1-4)         Low-Rise Multifamily    45235      38
# 21907        NonResidential               Medical Office    26930    6350
# 22585        NonResidential  Small- and Mid-Sized Office    30152    5680
# 22672        NonResidential                        Other    45750    4914
# 22838  Multifamily MR (5-9)         Mid-Rise Multifamily    32927     415
# 22962        NonResidential  Small- and Mid-Sized Office    76105   27307
# 23106  Multifamily MR (5-9)         Mid-Rise Multifamily    63414    6181
# 23522  Multifamily MR (5-9)         Mid-Rise Multifamily    35750    5041
# 23671        NonResidential  Small- and Mid-Sized Office    50333   18036
# 23742        NonResidential  Small- and Mid-Sized Office    43016    5400
# 23789  Multifamily HR (10+)        High-Rise Multifamily    66150   11290
# 23863        NonResidential                        Other    47836    7572
# 24070        NonResidential        Self-Storage Facility    48179    7132
# 24876        NonResidential        Self-Storage Facility    71874   31389
# 26218        NonResidential                        Hotel    41704    8584
# 26741  Multifamily LR (1-4)         Low-Rise Multifamily    63236    5958
# 27833        NonResidential                        Other    38879   11328
# 49693  Multifamily MR (5-9)         Mid-Rise Multifamily   375502  137061
# 50068        NonResidential                    Warehouse    52085    4222
#
#            a_i      a_u   a_u_o    a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 70      118858   155602       0   155602        0        36744       -36744
# 114     616891   920598  185014   735584        0       118693      -118693
# 245    1258280  1585960       0  1585960        0       327680      -327680
# 322      74003   100734       0   100734        0        26731       -26731
# 375     272410   396626  122624   274002        0         1592        -1592
# 410     272787   332067       0   332067        0        59280       -59280
# 434     109550   206950       0   206950        0        97400       -97400
# 441      79608   109017       0   109017        0        29409       -29409
# 521      53472    90000       0    90000        0        36528       -36528
# 549      50245    78672       0    78672        0        28427       -28427
# 551      55916    75844   18961    56883        0          967         -967
# 565      59850   102290   18575    83715        0        23865       -23865
# 650      55123    91706   34701    57005        0         1882        -1882
# 655     106740   117950       0   117950        0        11210       -11210
# 740      51374    77174       0    77174        0        25800       -25800
# 809      79920    95760       0    95760        0        15840       -15840
# 837      80874    87332       0    87332        0         6458        -6458
# 19690    85042    88144       0    88144        0         3102        -3102
# 20082    48220    61180       0    61180        0        12960       -12960
# 20398    32360    39320       0    39320        0         6960        -6960
# 21178    19497    26419       0    26419        0         6922        -6922
# 21313    40548    75058       0    75058        0        34510       -34510
# 21398    16200    28380       0    28380        0        12180       -12180
# 21565    39632    51510       0    51510        0        11878       -11878
# 21852    45197    45235       0    45235        0           38          -38
# 21907    20580    26930       0    26930        0         6350        -6350
# 22585    24472    30152    4968    25184        0          712         -712
# 22672    40836    45750    2900    42850        0         2014        -2014
# 22838    32512    32927       0    32927        0          415         -415
# 22962    48798    76105       0    76105        0        27307       -27307
# 23106    57233    63414       0    63414        0         6181        -6181
# 23522    30709    35750       0    35750        0         5041        -5041
# 23671    32297    50333       0    50333        0        18036       -18036
# 23742    37616    43016       0    43016        0         5400        -5400
# 23789    54860    66150       0    66150        0        11290       -11290
# 23863    40264    47836    4500    43336        0         3072        -3072
# 24070    41047    48179       0    48179        0         7132        -7132
# 24876    40485    71874       0    71874        0        31389       -31389
# 26218    33120    41704       0    41704        0         8584        -8584
# 26741    57278    63236       0    63236        0         5958        -5958
# 27833    27551    38879       0    38879        0        11328       -11328
# 49693   238441   375502       0   375502        0       137061      -137061
# 50068    47863    52085       0    52085        0         4222        -4222
#
#                                ListOfAllPropertyUseTypes  \
# id
# 70                                                 Hotel
# 114                               Office, Other, Parking
# 245       Other - Entertainment/Public Assembly, Parking
# 322                                               Office
# 375                                      Office, Parking
# 410                                                Hotel
# 434                                                Other
# 441                                                Hotel
# 521                                               Office
# 549                                               Office
# 551                               Office, Other, Parking
# 565                                      Office, Parking
# 650                               Office, Other, Parking
# 655    Multifamily Housing, Other - Lodging/Residenti...
# 740                                               Office
# 809                                               Office
# 837                           Non-Refrigerated Warehouse
# 19690                                Multifamily Housing
# 20082                                              Hotel
# 20398                                Social/Meeting Hall
# 21178                                             Office
# 21313                                   Worship Facility
# 21398                                             Office
# 21565                                Multifamily Housing
# 21852                                Multifamily Housing
# 21907                                     Medical Office
# 22585                                    Office, Parking
# 22672                                     Other, Parking
# 22838                                Multifamily Housing
# 22962                                             Office
# 23106                                Multifamily Housing
# 23522                                Multifamily Housing
# 23671                                             Office
# 23742                                             Office
# 23789                                Multifamily Housing
# 23863               Other - Lodging/Residential, Parking
# 24070                              Self-Storage Facility
# 24876                              Self-Storage Facility
# 26218                                              Hotel
# 26741                                Multifamily Housing
# 27833                Urgent Care/Clinic/Other Outpatient
# 49693                                Multifamily Housing
# 50068                         Non-Refrigerated Warehouse
#
#                       LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 70                                     Hotel                   155602.0
# 114                                   Office                   729584.0
# 245    Other - Entertainment/Public Assembly                  1585960.0
# 322                                   Office                   100734.0
# 375                                   Office                   274002.0
# 410                                    Hotel                   332067.0
# 434                                    Other                   206950.0
# 441                                    Hotel                   109017.0
# 521                                   Office                    90000.0
# 549                                   Office                    78672.0
# 551                                    Other                    28442.0
# 565                                   Office                    83715.0
# 650                                   Office                    53281.0
# 655                      Multifamily Housing                   117950.0
# 740                                   Office                    77174.0
# 809                                   Office                    95760.0
# 837               Non-Refrigerated Warehouse                    87332.0
# 19690                    Multifamily Housing                    88144.0
# 20082                                  Hotel                    61180.0
# 20398                    Social/Meeting Hall                    39320.0
# 21178                                 Office                    26419.0
# 21313                       Worship Facility                    75058.0
# 21398                                 Office                    28380.0
# 21565                    Multifamily Housing                    51510.0
# 21852                    Multifamily Housing                    45235.0
# 21907                         Medical Office                    26930.0
# 22585                                 Office                    25184.0
# 22672                                  Other                    42850.0
# 22838                    Multifamily Housing                    32927.0
# 22962                                 Office                    76105.0
# 23106                    Multifamily Housing                    63414.0
# 23522                    Multifamily Housing                    35750.0
# 23671                                 Office                    50333.0
# 23742                                 Office                    43016.0
# 23789                    Multifamily Housing                    66150.0
# 23863            Other - Lodging/Residential                    43336.0
# 24070                  Self-Storage Facility                    48179.0
# 24876                  Self-Storage Facility                    71874.0
# 26218                                  Hotel                    41704.0
# 26741                    Multifamily Housing                    63236.0
# 27833    Urgent Care/Clinic/Other Outpatient                    38879.0
# 49693                    Multifamily Housing                   375502.0
# 50068             Non-Refrigerated Warehouse                    52085.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 70                             NaN                              NaN
# 114                        Parking                         185014.0
# 245                        Parking                              0.0
# 322                            NaN                              NaN
# 375                        Parking                         122624.0
# 410                            NaN                              NaN
# 434                            NaN                              NaN
# 441                            NaN                              NaN
# 521                            NaN                              NaN
# 549                            NaN                              NaN
# 551                         Office                          28441.0
# 565                        Parking                          18575.0
# 650                        Parking                          34701.0
# 655                            NaN                              NaN
# 740                            NaN                              NaN
# 809                            NaN                              NaN
# 837                            NaN                              NaN
# 19690                          NaN                              NaN
# 20082                          NaN                              NaN
# 20398                          NaN                              NaN
# 21178                          NaN                              NaN
# 21313                          NaN                              NaN
# 21398                          NaN                              NaN
# 21565                          NaN                              NaN
# 21852                          NaN                              NaN
# 21907                          NaN                              NaN
# 22585                      Parking                           4968.0
# 22672                      Parking                           2900.0
# 22838                          NaN                              NaN
# 22962                          NaN                              NaN
# 23106                          NaN                              NaN
# 23522                          NaN                              NaN
# 23671                          NaN                              NaN
# 23742                          NaN                              NaN
# 23789                          NaN                              NaN
# 23863                      Parking                           4500.0
# 24070                          NaN                              NaN
# 24876                          NaN                              NaN
# 26218                          NaN                              NaN
# 26741                          NaN                              NaN
# 27833                          NaN                              NaN
# 49693                          NaN                              NaN
# 50068                          NaN                              NaN
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 70                            NaN                             NaN
# 114                         Other                          6000.0
# 245                           NaN                             NaN
# 322                           NaN                             NaN
# 375                           NaN                             NaN
# 410                           NaN                             NaN
# 434                           NaN                             NaN
# 441                           NaN                             NaN
# 521                           NaN                             NaN
# 549                           NaN                             NaN
# 551                       Parking                         18961.0
# 565                           NaN                             NaN
# 650                         Other                          3724.0
# 655                           NaN                             NaN
# 740                           NaN                             NaN
# 809                           NaN                             NaN
# 837                           NaN                             NaN
# 19690                         NaN                             NaN
# 20082                         NaN                             NaN
# 20398                         NaN                             NaN
# 21178                         NaN                             NaN
# 21313                         NaN                             NaN
# 21398                         NaN                             NaN
# 21565                         NaN                             NaN
# 21852                         NaN                             NaN
# 21907                         NaN                             NaN
# 22585                         NaN                             NaN
# 22672                         NaN                             NaN
# 22838                         NaN                             NaN
# 22962                         NaN                             NaN
# 23106                         NaN                             NaN
# 23522                         NaN                             NaN
# 23671                         NaN                             NaN
# 23742                         NaN                             NaN
# 23789                         NaN                             NaN
# 23863                         NaN                             NaN
# 24070                         NaN                             NaN
# 24876                         NaN                             NaN
# 26218                         NaN                             NaN
# 26741                         NaN                             NaN
# 27833                         NaN                             NaN
# 49693                         NaN                             NaN
# 50068                         NaN                             NaN

# %% [markdown]
# # $\Delta a \gt 0 \Leftrightarrow a \gt a_u$<br/>Classes 3 à 7<br/>982 cas, 30 % des cas

# %%
pos_a_diff = _table[a_gt_a_u]
display(pos_a_diff)
# Out:
#                       btype                 ptype       a     a_o     a_i  \
# id
# 3            NonResidential                 Hotel  956110  196718  759392
# 9        Nonresidential COS                 Other   97288   37198   60090
# 10           NonResidential                 Hotel   83008       0   83008
# 13     Multifamily MR (5-9)  Mid-Rise Multifamily   63712    1496   62216
# 15           NonResidential                 Hotel  153163   19279  133884
# ...                     ...                   ...     ...     ...     ...
# 50196    Nonresidential COS    Mixed Use Property   20616       0   20616
# 50207    Nonresidential COS                 Other   16795       0   16795
# 50219    Nonresidential COS    Mixed Use Property   20050       0   20050
# 50225    Nonresidential COS    Mixed Use Property   14101       0   14101
# 50226    Nonresidential COS    Mixed Use Property   18258       0   18258
#
#           a_u  a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i
# id
# 3      756493      0  756493   199617       196718         2899
# 9       88830      0   88830     8458        37198       -28740
# 10      81352      0   81352     1656            0         1656
# 13      56132      0   56132     7580         1496         6084
# 15     133884      0  133884    19279        19279            0
# ...       ...    ...     ...      ...          ...          ...
# 50196   19841      0   19841      775            0          775
# 50207   16229      0   16229      566            0          566
# 50219   19613      0   19613      437            0          437
# 50225   13586      0   13586      515            0          515
# 50226   17379      0   17379      879            0          879
#
# [982 rows x 11 columns]

# %% [markdown]
# ## Incohérences de classe 3<br/>23 cas, 1 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \gt 0$
# * $\Delta a_i \gt 0$
# * $\Delta a_o = 0$

# %%
class_3_members = _table[a_class[3]]
class_3_members_details = join_use_allocation(class_3_members, data)
print(class_3_members_details.shape[0])
display(class_3_members_details)
# Out:
# 23
#                       btype                        ptype       a     a_o  \
# id
# 15           NonResidential                        Hotel  153163   19279
# 476          NonResidential                 Large Office  226592   95000
# 495          NonResidential               Medical Office  191276   95281
# 500          NonResidential  Supermarket / Grocery Store  308965  187878
# 692          NonResidential                        Other  275982  197130
# 1281         NonResidential                 Large Office  113944   48510
# 19498  Multifamily LR (1-4)           Mixed Use Property   37849   14997
# 19679  Multifamily HR (10+)        High-Rise Multifamily   91600   12365
# 19925  Multifamily HR (10+)        High-Rise Multifamily  393841   67222
# 20730  Multifamily MR (5-9)         Mid-Rise Multifamily   91703    7565
# 21291  Multifamily MR (5-9)         Mid-Rise Multifamily  101192   41840
# 21370  Multifamily HR (10+)        High-Rise Multifamily  333244   76762
# 21582        NonResidential                 Retail Store   25194    3764
# 21776  Multifamily HR (10+)        High-Rise Multifamily  330693     260
# 25047  Multifamily LR (1-4)         Low-Rise Multifamily   36383    7030
# 25897  Multifamily MR (5-9)         Mid-Rise Multifamily   30796    9502
# 26514  Multifamily LR (1-4)         Low-Rise Multifamily   30034    1874
# 26519  Multifamily MR (5-9)         Mid-Rise Multifamily   30481    8076
# 26989  Multifamily LR (1-4)        Senior Care Community   76699   19133
# 27417  Multifamily MR (5-9)         Mid-Rise Multifamily   82254   21764
# 27721    Nonresidential COS                        Other   27376   14570
# 49998        NonResidential        Self-Storage Facility  101580   14004
# 50098  Multifamily LR (1-4)         Low-Rise Multifamily   20246    2580
#
#           a_i     a_u   a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 15     133884  133884       0  133884    19279        19279            0
# 476    131592  214770   83178  131592    11822        11822            0
# 495     95995   95995       0   95995    95281        95281            0
# 500    121087  121087       0  121087   187878       187878            0
# 692     78852  275892  197040   78852       90           90            0
# 1281    65434   65434       0   65434    48510        48510            0
# 19498   22852   28352    5500   22852     9497         9497            0
# 19679   79235   79235       0   79235    12365        12365            0
# 19925  326619  326619       0  326619    67222        67222            0
# 20730   84138   88638    4500   84138     3065         3065            0
# 21291   59352   59352       0   59352    41840        41840            0
# 21370  256482  256482       0  256482    76762        76762            0
# 21582   21430   21430       0   21430     3764         3764            0
# 21776  330433  330433       0  330433      260          260            0
# 25047   29353   29353       0   29353     7030         7030            0
# 25897   21294   21294       0   21294     9502         9502            0
# 26514   28160   28160       0   28160     1874         1874            0
# 26519   22405   27723    5318   22405     2758         2758            0
# 26989   57566   57566       0   57566    19133        19133            0
# 27417   60490   60490       0   60490    21764        21764            0
# 27721   12806   12806       0   12806    14570        14570            0
# 49998   87576   87576       0   87576    14004        14004            0
# 50098   17666   17666       0   17666     2580         2580            0
#
#                         ListOfAllPropertyUseTypes     LargestPropertyUseType  \
# id
# 15                                          Hotel                      Hotel
# 476                               Office, Parking                     Office
# 495                                Medical Office             Medical Office
# 500            Parking, Supermarket/Grocery Store  Supermarket/Grocery Store
# 692                               Office, Parking                    Parking
# 1281                                       Office                     Office
# 19498        Multifamily Housing, Office, Parking        Multifamily Housing
# 19679                 Multifamily Housing, Office        Multifamily Housing
# 19925  Multifamily Housing, Parking, Retail Store        Multifamily Housing
# 20730                Multifamily Housing, Parking        Multifamily Housing
# 21291                         Multifamily Housing        Multifamily Housing
# 21370                         Multifamily Housing        Multifamily Housing
# 21582        Medical Office, Office, Retail Store               Retail Store
# 21776                         Multifamily Housing        Multifamily Housing
# 25047        Multifamily Housing, Office, Parking        Multifamily Housing
# 25897                         Multifamily Housing        Multifamily Housing
# 26514                         Multifamily Housing        Multifamily Housing
# 26519  Multifamily Housing, Parking, Retail Store        Multifamily Housing
# 26989              Parking, Senior Care Community      Senior Care Community
# 27417                         Multifamily Housing        Multifamily Housing
# 27721                            Library, Parking                    Library
# 49998                       Self-Storage Facility      Self-Storage Facility
# 50098                         Multifamily Housing        Multifamily Housing
#
#        LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# id
# 15                      133884.0                          NaN
# 476                     131592.0                      Parking
# 495                      95995.0                          NaN
# 500                     121087.0                      Parking
# 692                     197040.0                       Office
# 1281                     65434.0                          NaN
# 19498                    11980.0                       Office
# 19679                    65706.0                       Office
# 19925                   302922.0                 Retail Store
# 20730                    84138.0                      Parking
# 21291                    59352.0                          NaN
# 21370                   256482.0                          NaN
# 21582                    10751.0               Medical Office
# 21776                   330433.0                          NaN
# 25047                    25153.0                       Office
# 25897                    21294.0                          NaN
# 26514                    28160.0                          NaN
# 26519                    17256.0                      Parking
# 26989                    57566.0                      Parking
# 27417                    60490.0                          NaN
# 27721                    12806.0                      Parking
# 49998                    87576.0                          NaN
# 50098                    17666.0                          NaN
#
#        SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# id
# 15                                 NaN                         NaN
# 476                            83178.0                         NaN
# 495                                NaN                         NaN
# 500                                0.0                     Parking
# 692                            78852.0                         NaN
# 1281                               NaN                         NaN
# 19498                          10872.0                     Parking
# 19679                          13529.0                         NaN
# 19925                          23697.0                     Parking
# 20730                           4500.0                         NaN
# 21291                              NaN                         NaN
# 21370                              NaN                         NaN
# 21582                           8044.0                      Office
# 21776                              NaN                         NaN
# 25047                           4200.0                     Parking
# 25897                              NaN                         NaN
# 26514                              NaN                         NaN
# 26519                           5318.0                Retail Store
# 26989                              0.0                         NaN
# 27417                              NaN                         NaN
# 27721                              0.0                         NaN
# 49998                              NaN                         NaN
# 50098                              NaN                         NaN
#
#        ThirdLargestPropertyUseTypeGFA
# id
# 15                                NaN
# 476                               NaN
# 495                               NaN
# 500                               0.0
# 692                               NaN
# 1281                              NaN
# 19498                          5500.0
# 19679                             NaN
# 19925                             0.0
# 20730                             NaN
# 21291                             NaN
# 21370                             NaN
# 21582                          2635.0
# 21776                             NaN
# 25047                             0.0
# 25897                             NaN
# 26514                             NaN
# 26519                          5149.0
# 26989                             NaN
# 27417                             NaN
# 27721                             NaN
# 49998                             NaN
# 50098                             NaN

# %% [markdown]
# ## Incohérences de classe 4<br/>621 cas, 19 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \gt 0$
# * $\Delta a_i \gt 0$
# * $\Delta a_o = 0$

# %%
class_4_members = _table[a_class[4]]
class_4_members_details = join_use_allocation(class_4_members, data)
print(class_4_members_details.shape[0])
display(class_4_members_details)
# Out:
# 621
#                     btype                        ptype       a  a_o     a_i  \
# id
# 10         NonResidential                        Hotel   83008    0   83008
# 24         NonResidential           Mixed Use Property   57452    0   57452
# 26         NonResidential                        Other  540360    0  540360
# 30         NonResidential                   University  126593    0  126593
# 38         NonResidential  Small- and Mid-Sized Office   87262    0   87262
# ...                   ...                          ...     ...  ...     ...
# 50196  Nonresidential COS           Mixed Use Property   20616    0   20616
# 50207  Nonresidential COS                        Other   16795    0   16795
# 50219  Nonresidential COS           Mixed Use Property   20050    0   20050
# 50225  Nonresidential COS           Mixed Use Property   14101    0   14101
# 50226  Nonresidential COS           Mixed Use Property   18258    0   18258
#
#           a_u  a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 10      81352      0   81352     1656            0         1656
# 24      41688      0   41688    15764            0        15764
# 26     537150      0  537150     3210            0         3210
# 30     125000      0  125000     1593            0         1593
# 38      63403      0   63403    23859            0        23859
# ...       ...    ...     ...      ...          ...          ...
# 50196   19841      0   19841      775            0          775
# 50207   16229      0   16229      566            0          566
# 50219   19613      0   19613      437            0          437
# 50225   13586      0   13586      515            0          515
# 50226   17379      0   17379      879            0          879
#
#                                ListOfAllPropertyUseTypes  \
# id
# 10                                                 Hotel
# 24     Office, Other, Other - Lodging/Residential, Re...
# 26                                            Courthouse
# 30                                    College/University
# 38     K-12 School, Multifamily Housing, Office, Othe...
# ...                                                  ...
# 50196  Fitness Center/Health Club/Gym, Office, Other ...
# 50207  Fitness Center/Health Club/Gym, Food Service, ...
# 50219  Fitness Center/Health Club/Gym, Office, Other ...
# 50225  Fitness Center/Health Club/Gym, Food Service, ...
# 50226  Fitness Center/Health Club/Gym, Food Service, ...
#
#       LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 10                     Hotel                    81352.0
# 24       Social/Meeting Hall                    16442.0
# 26                Courthouse                   537150.0
# 30        College/University                   125000.0
# 38                    Office                    40943.0
# ...                      ...                        ...
# 50196     Other - Recreation                     9900.0
# 50207     Other - Recreation                     8680.0
# 50219     Other - Recreation                     8108.0
# 50225     Other - Recreation                     6601.0
# 50226     Other - Recreation                     8271.0
#
#          SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 10                                NaN                              NaN
# 24                         Restaurant                          15505.0
# 26                                NaN                              NaN
# 30                                NaN                              NaN
# 38                        K-12 School                          18153.0
# ...                               ...                              ...
# 50196  Fitness Center/Health Club/Gym                           8577.0
# 50207  Fitness Center/Health Club/Gym                           7014.0
# 50219  Fitness Center/Health Club/Gym                           7726.0
# 50225  Fitness Center/Health Club/Gym                           6501.0
# 50226  Fitness Center/Health Club/Gym                           8000.0
#
#                  ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 10                                       NaN                             NaN
# 24                                    Office                          9741.0
# 26                                       NaN                             NaN
# 30                                       NaN                             NaN
# 38     Other - Entertainment/Public Assembly                          4307.0
# ...                                      ...                             ...
# 50196                     Pre-school/Daycare                          1364.0
# 50207                     Pre-school/Daycare                           535.0
# 50219                                 Office                          3779.0
# 50225                     Pre-school/Daycare                           484.0
# 50226                     Pre-school/Daycare                          1108.0
#
# [621 rows x 18 columns]

# %% [markdown]
# ## Incohérences de classe 5<br/>96 cas, 3 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \gt 0$
# * $\Delta a_i \gt 0$
# * $\Delta a_o \gt 0$

# %%
class_5_members = _table[a_class[5]]
class_5_members_details = join_use_allocation(class_5_members, data)
print(class_5_members_details.shape[0])
display(class_5_members_details)
# Out:
# 96
#                       btype                  ptype       a     a_o     a_i  \
# id
# 3            NonResidential                  Hotel  956110  196718  759392
# 13     Multifamily MR (5-9)   Mid-Rise Multifamily   63712    1496   62216
# 33           NonResidential                  Hotel  171866   38281  133585
# 35           NonResidential                  Hotel   68410   16200   52210
# 68           NonResidential                  Hotel  150453   34735  115718
# ...                     ...                    ...     ...     ...     ...
# 50083  Multifamily MR (5-9)   Mid-Rise Multifamily  175844   52045  123799
# 50075  Multifamily MR (5-9)   Mid-Rise Multifamily  260051   90503  169548
# 50078  Multifamily HR (10+)  High-Rise Multifamily  149976   12223  137753
# 50082  Multifamily LR (1-4)   Low-Rise Multifamily   36685    8254   28431
# 50094        NonResidential     Mixed Use Property  345290   85028  260262
#
#           a_u  a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 3      756493      0  756493   199617       196718         2899
# 13      56132      0   56132     7580         1496         6084
# 33     128909      0  128909    42957        38281         4676
# 35      47994      0   47994    20416        16200         4216
# 68     110547      0  110547    39906        34735         5171
# ...       ...    ...     ...      ...          ...          ...
# 50083  123554  24000   99554    52290        28045        24245
# 50075  210125  64341  145784    49926        26162        23764
# 50078  138004   5986  132018    11972         6237         5735
# 50082       0      0       0    36685         8254        28431
# 50094  342023  84002  258021     3267         1026         2241
#
#                                ListOfAllPropertyUseTypes  \
# id
# 3                                                  Hotel
# 13                                   Multifamily Housing
# 33                                                 Hotel
# 35                                                 Hotel
# 68                                                 Hotel
# ...                                                  ...
# 50083                       Multifamily Housing, Parking
# 50075                       Multifamily Housing, Parking
# 50078  College/University, Multifamily Housing, Offic...
# 50082                                                NaN
# 50094  Data Center, Laboratory, Museum, Office, Other...
#
#       LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 3                      Hotel                   756493.0
# 13       Multifamily Housing                    56132.0
# 33                     Hotel                   128909.0
# 35                     Hotel                    47994.0
# 68                     Hotel                   107547.0
# ...                      ...                        ...
# 50083    Multifamily Housing                    99554.0
# 50075    Multifamily Housing                   145784.0
# 50078    Multifamily Housing                   115768.0
# 50082                    NaN                        NaN
# 50094             Laboratory                   151523.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 3                              NaN                              NaN
# 13                             NaN                              NaN
# 33                             NaN                              NaN
# 35                             NaN                              NaN
# 68                      Restaurant                           3000.0
# ...                            ...                              ...
# 50083                      Parking                          24000.0
# 50075                      Parking                          64341.0
# 50078                       Office                          12503.0
# 50082                          NaN                              NaN
# 50094                       Office                         106498.0
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 3                             NaN                             NaN
# 13                            NaN                             NaN
# 33                            NaN                             NaN
# 35                            NaN                             NaN
# 68                            NaN                             NaN
# ...                           ...                             ...
# 50083                         NaN                             NaN
# 50075                         NaN                             NaN
# 50078          College/University                          9733.0
# 50082                         NaN                             NaN
# 50094                     Parking                         84002.0
#
# [96 rows x 18 columns]

# %% [markdown]
# ## Incohérences de classe 6<br/>179 cas, 6 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \gt 0$
# * $\Delta a_i \gt 0$
# * $\Delta a_o \lt 0$

# %%
class_6_members = _table[a_class[6]]
class_6_members_details = join_use_allocation(class_6_members, data)
print(class_6_members_details.shape[0])
display(class_6_members_details)
# Out:
# 179
#                       btype                        ptype       a    a_o  \
# id
# 65           NonResidential                        Hotel   71150      0
# 96           NonResidential           Mixed Use Property   99780   9341
# 113          NonResidential  Small- and Mid-Sized Office   66240   2352
# 168          NonResidential                        Hotel  162222  14200
# 200          NonResidential                        Other   55442      0
# ...                     ...                          ...     ...    ...
# 50027  Multifamily MR (5-9)         Mid-Rise Multifamily   62049      0
# 50030  Multifamily MR (5-9)         Mid-Rise Multifamily  283479      0
# 50031        NonResidential                 Large Office  513816      0
# 50058  Multifamily LR (1-4)         Low-Rise Multifamily   48230      0
# 50059  Multifamily LR (1-4)         Low-Rise Multifamily   53100      0
#
#           a_i     a_u   a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 65      71150   64674   13730   50944     6476       -13730        20206
# 96      90439   78062   20868   57194    21718       -11527        33245
# 113     63888   55632    5304   50328    10608        -2952        13560
# 168    148022  146394   32692  113702    15828       -18492        34320
# 200     55442   52665   15385   37280     2777       -15385        18162
# ...       ...     ...     ...     ...      ...          ...          ...
# 50027   62049   47290   16810   30480    14759       -16810        31569
# 50030  283479  252168   86340  165828    31311       -86340       117651
# 50031  513816  511785  151658  360127     2031      -151658       153689
# 50058   48230   42600   16425   26175     5630       -16425        22055
# 50059   53100   52761   20754   32007      339       -20754        21093
#
#                                ListOfAllPropertyUseTypes  \
# id
# 65              Hotel, Parking, Restaurant, Retail Store
# 96     Data Center, Medical Office, Non-Refrigerated ...
# 113    Data Center, Distribution Center, Office, Park...
# 168                                       Hotel, Parking
# 200            Financial Office, Medical Office, Parking
# ...                                                  ...
# 50027                       Multifamily Housing, Parking
# 50030                       Multifamily Housing, Parking
# 50031                        Office, Parking, Restaurant
# 50058                       Multifamily Housing, Parking
# 50059                       Multifamily Housing, Parking
#
#       LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 65                     Hotel                    41340.0
# 96            Medical Office                    40174.0
# 113                   Office                    45900.0
# 168                    Hotel                   113702.0
# 200         Financial Office                    28636.0
# ...                      ...                        ...
# 50027    Multifamily Housing                    30480.0
# 50030    Multifamily Housing                   165828.0
# 50031                 Office                   359040.0
# 50058    Multifamily Housing                    26175.0
# 50059    Multifamily Housing                    32007.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 65                         Parking                          13730.0
# 96                         Parking                          20868.0
# 113                    Data Center                           5181.0
# 168                        Parking                          32692.0
# 200                        Parking                          15385.0
# ...                            ...                              ...
# 50027                      Parking                          16810.0
# 50030                      Parking                          86340.0
# 50031                      Parking                         151658.0
# 50058                      Parking                          16425.0
# 50059                      Parking                          20754.0
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 65                   Retail Store                          9604.0
# 96                         Office                         17020.0
# 113           Distribution Center                          4551.0
# 168                           NaN                             NaN
# 200                Medical Office                          8644.0
# ...                           ...                             ...
# 50027                         NaN                             NaN
# 50030                         NaN                             NaN
# 50031                  Restaurant                          1087.0
# 50058                         NaN                             NaN
# 50059                         NaN                             NaN
#
# [179 rows x 18 columns]

# %% [markdown]
# ## Incohérence de classe 7<br/>63 cas, 2 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \gt 0$
# * $\Delta a_i \lt 0$
# * $\Delta a_o \gt 0$

# %%
class_7_members = _table[a_class[7]]
class_7_members_details = join_use_allocation(class_7_members, data)
print(class_7_members_details.shape[0])
display(class_7_members_details)
# Out:
# 63
#                       btype                        ptype       a     a_o  \
# id
# 9        Nonresidential COS                        Other   97288   37198
# 115          NonResidential  Small- and Mid-Sized Office   76213   25930
# 183          NonResidential               Residence Hall  139600   37500
# 338          NonResidential                        Other  299070   68432
# 211                  Campus                   University  694072  111625
# ...                     ...                          ...     ...     ...
# 27252  Multifamily MR (5-9)         Mid-Rise Multifamily  121773   25568
# 27378        NonResidential  Supermarket / Grocery Store   76585   38585
# 49867        NonResidential                 Large Office  333714  146687
# 49945        NonResidential        Senior Care Community  197395  156000
# 50037        NonResidential                 Large Office  480702  163260
#
#           a_i     a_u   a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 9       60090   88830       0   88830     8458        37198       -28740
# 115     50283   72406   21454   50952     3807         4476         -669
# 183    102100  135520       0  135520     4080        37500       -33420
# 338    230638  250000       0  250000    49070        68432       -19362
# 211    582447  667335       0  667335    26737       111625       -84888
# ...       ...     ...     ...     ...      ...          ...          ...
# 27252   96205  121000       0  121000      773        25568       -24795
# 27378   38000   41447       0   41447    35138        38585        -3447
# 49867  187027  324765  133432  191333     8949        13255        -4306
# 49945   41395   43036       0   43036   154359       156000        -1641
# 50037  317442  478491  136594  341897     2211        26666       -24455
#
#                                ListOfAllPropertyUseTypes  \
# id
# 9                                         Police Station
# 115                               Office, Other, Parking
# 183                             Residence Hall/Dormitory
# 338                                                Other
# 211                                   College/University
# ...                                                  ...
# 27252                                Multifamily Housing
# 27378                 Parking, Supermarket/Grocery Store
# 49867                                    Office, Parking
# 49945  Office, Other - Public Services, Personal Serv...
# 50037                                    Office, Parking
#
#           LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 9                 Police Station                    88830.0
# 115                       Office                    48546.0
# 183     Residence Hall/Dormitory                   135520.0
# 338                        Other                   250000.0
# 211           College/University                   667335.0
# ...                          ...                        ...
# 27252        Multifamily Housing                   121000.0
# 27378  Supermarket/Grocery Store                    41447.0
# 49867                     Office                   191333.0
# 49945      Senior Care Community                    38800.0
# 50037                     Office                   341897.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 9                              NaN                              NaN
# 115                        Parking                          21454.0
# 183                            NaN                              NaN
# 338                            NaN                              NaN
# 211                            NaN                              NaN
# ...                            ...                              ...
# 27252                          NaN                              NaN
# 27378                      Parking                              0.0
# 49867                      Parking                         133432.0
# 49945      Other - Public Services                           3650.0
# 50037                      Parking                         136594.0
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 9                             NaN                             NaN
# 115                         Other                          2406.0
# 183                           NaN                             NaN
# 338                           NaN                             NaN
# 211                           NaN                             NaN
# ...                           ...                             ...
# 27252                         NaN                             NaN
# 27378                         NaN                             NaN
# 49867                         NaN                             NaN
# 49945                      Office                           586.0
# 50037                         NaN                             NaN
#
# [63 rows x 18 columns]

# %% [markdown]
# # $\Delta a \lt 0 \Leftrightarrow a \lt a_u$<br/>Classes 8 à 12<br/>726 cas, 23 % des cas

# %%
neg_a_diff = _table[a_lt_a_u]
display(neg_a_diff)
# Out:
#                       btype                 ptype       a    a_o     a_i  \
# id
# 8            NonResidential                 Hotel  175580  62000  113580
# 16           NonResidential                 Hotel  333176  61161  272015
# 18           NonResidential                 Hotel  315952  57600  258352
# 19           NonResidential                 Hotel   92190  25200   66990
# 21       Nonresidential COS                 Other  412000  57000  355000
# ...                     ...                   ...     ...    ...     ...
# 50089  Multifamily LR (1-4)  Low-Rise Multifamily   25442    604   24838
# 50090  Multifamily MR (5-9)  Mid-Rise Multifamily   63825   4850   58975
# 50093  Multifamily MR (5-9)  Mid-Rise Multifamily   86045   8908   77137
# 50095  Multifamily MR (5-9)  Mid-Rise Multifamily  208136  58818  149318
# 50101     Nonresidential WA            University   68072      0   68072
#
#           a_u  a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i
# id
# 8      191454  68009  123445   -15874        -6009        -9865
# 16     336640      0  336640    -3464        61161       -64625
# 18     353111  57600  295511   -37159            0       -37159
# 19      92590  25200   67390     -400            0         -400
# 21     414987  49000  365987    -2987         8000       -10987
# ...       ...    ...     ...      ...          ...          ...
# 50089   34164   5582   28582    -8722        -4978        -3744
# 50090   71241      0   71241    -7416         4850       -12266
# 50093   87854   8126   79728    -1809          782        -2591
# 50095  212938  44717  168221    -4802        14101       -18903
# 50101   68916      0   68916     -844            0         -844
#
# [726 rows x 11 columns]

# %% [markdown]
# ## Incohérences de classe 8<br/>117 cas, 4 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \lt 0$
# * $\Delta a_i = 0$
# * $\Delta a_o \lt 0$

# %%
class_8_members = _table[a_class[8]]
class_8_members_details = join_use_allocation(class_8_members, data)
print(class_8_members_details.shape[0])
display(class_8_members_details)
# Out:
# 117
#                       btype                 ptype       a  a_o     a_i  \
# id
# 144          NonResidential                 Hotel  190980    0  190980
# 387          NonResidential          Large Office  298426    0  298426
# 477                  Campus                 Other  535947    0  535947
# 19511  Multifamily LR (1-4)  Low-Rise Multifamily   21888    0   21888
# 19792  Multifamily MR (5-9)  Mid-Rise Multifamily   21715    0   21715
# ...                     ...                   ...     ...  ...     ...
# 50017  Multifamily MR (5-9)  Mid-Rise Multifamily   70191    0   70191
# 50018  Multifamily MR (5-9)  Mid-Rise Multifamily   82087    0   82087
# 50023  Multifamily LR (1-4)  Low-Rise Multifamily  182378    0  182378
# 50028  Multifamily LR (1-4)  Low-Rise Multifamily   43566    0   43566
# 50039        NonResidential                 Other  108036    0  108036
#
#           a_u   a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 144    210031   19051  190980   -19051       -19051            0
# 387    496176  197750  298426  -197750      -197750            0
# 477    639930  103983  535947  -103983      -103983            0
# 19511   27388    5500   21888    -5500        -5500            0
# 19792   26005    4290   21715    -4290        -4290            0
# ...       ...     ...     ...      ...          ...          ...
# 50017   96478   26287   70191   -26287       -26287            0
# 50018  107281   25194   82087   -25194       -25194            0
# 50023  227178   44800  182378   -44800       -44800            0
# 50028   52168    8602   43566    -8602        -8602            0
# 50039  310207  202171  108036  -202171      -202171            0
#
#                 ListOfAllPropertyUseTypes LargestPropertyUseType  \
# id
# 144                        Hotel, Parking                  Hotel
# 387    Office, Other - Education, Parking                 Office
# 477                        Other, Parking                  Other
# 19511        Multifamily Housing, Parking    Multifamily Housing
# 19792        Multifamily Housing, Parking    Multifamily Housing
# ...                                   ...                    ...
# 50017        Multifamily Housing, Parking    Multifamily Housing
# 50018        Multifamily Housing, Parking    Multifamily Housing
# 50023        Multifamily Housing, Parking    Multifamily Housing
# 50028        Multifamily Housing, Parking    Multifamily Housing
# 50039      Automobile Dealership, Parking                Parking
#
#        LargestPropertyUseTypeGFA SecondLargestPropertyUseType  \
# id
# 144                     190980.0                      Parking
# 387                     286538.0                      Parking
# 477                     535947.0                      Parking
# 19511                    21888.0                      Parking
# 19792                    21715.0                      Parking
# ...                          ...                          ...
# 50017                    70191.0                      Parking
# 50018                    82087.0                      Parking
# 50023                   182378.0                      Parking
# 50028                    43566.0                      Parking
# 50039                   202171.0        Automobile Dealership
#
#        SecondLargestPropertyUseTypeGFA ThirdLargestPropertyUseType  \
# id
# 144                            19051.0                         NaN
# 387                           197750.0           Other - Education
# 477                           103983.0                         NaN
# 19511                           5500.0                         NaN
# 19792                           4290.0                         NaN
# ...                                ...                         ...
# 50017                          26287.0                         NaN
# 50018                          25194.0                         NaN
# 50023                          44800.0                         NaN
# 50028                           8602.0                         NaN
# 50039                         108036.0                         NaN
#
#        ThirdLargestPropertyUseTypeGFA
# id
# 144                               NaN
# 387                           11888.0
# 477                               NaN
# 19511                             NaN
# 19792                             NaN
# ...                               ...
# 50017                             NaN
# 50018                             NaN
# 50023                             NaN
# 50028                             NaN
# 50039                             NaN
#
# [117 rows x 18 columns]

# %% [markdown]
# ## Incohérences de classe 9<br/>107 cas, 3 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \lt 0$
# * $\Delta a_i \gt 0$
# * $\Delta a_o \lt 0$

# %%
class_9_members = _table[a_class[9]]
class_9_members_details = join_use_allocation(class_9_members, data)
print(class_9_members_details.shape[0])
display(class_9_members_details)
# Out:
# 107
#                       btype                        ptype       a    a_o  \
# id
# 32           NonResidential                        Hotel  158676  30301
# 100          NonResidential                 Large Office  316306      0
# 102          NonResidential                        Hotel  282863  44766
# 238      Nonresidential COS  Small- and Mid-Sized Office   91130      0
# 264          NonResidential           Mixed Use Property  110785      0
# ...                     ...                          ...     ...    ...
# 49986  Multifamily MR (5-9)               Residence Hall   69451      0
# 50003  Multifamily LR (1-4)         Low-Rise Multifamily   21267      0
# 50016  Multifamily MR (5-9)         Mid-Rise Multifamily  418285      0
# 50046  Multifamily MR (5-9)         Mid-Rise Multifamily  110964      0
# 50084  Multifamily MR (5-9)         Mid-Rise Multifamily  213952  51739
#
#           a_i     a_u   a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 32     128375  159176   42000  117176     -500       -11699        11199
# 100    316306  427691  150726  276965  -111385      -150726        39341
# 102    238097  287325   51537  235788    -4462        -6771         2309
# 238     91130  102699   11850   90849   -11569       -11850          281
# 264    110785  136922   29839  107083   -26137       -29839         3702
# ...       ...     ...     ...     ...      ...          ...          ...
# 49986   69451   69912   23084   46828     -461       -23084        22623
# 50003   21267   23398    3765   19633    -2131        -3765         1634
# 50016  418285  545910  127633  418277  -127625      -127633            8
# 50046  110964  131645   27261  104384   -20681       -27261         6580
# 50084  162213  289913  135000  154913   -75961       -83261         7300
#
#                                ListOfAllPropertyUseTypes  \
# id
# 32           Hotel, Parking, Retail Store, Swimming Pool
# 100                 Office, Other, Parking, Retail Store
# 102                                       Hotel, Parking
# 238    Data Center, Distribution Center, Office, Othe...
# 264    Financial Office, Multifamily Housing, Parking...
# ...                                                  ...
# 49986                  Parking, Residence Hall/Dormitory
# 50003                       Multifamily Housing, Parking
# 50016                       Multifamily Housing, Parking
# 50046                       Multifamily Housing, Parking
# 50084                       Multifamily Housing, Parking
#
#          LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 32                        Hotel                   112676.0
# 100                      Office                   261826.0
# 102                       Hotel                   235788.0
# 238                      Office                    57968.0
# 264         Multifamily Housing                    58563.0
# ...                         ...                        ...
# 49986  Residence Hall/Dormitory                    46828.0
# 50003       Multifamily Housing                    19633.0
# 50016       Multifamily Housing                   418277.0
# 50046       Multifamily Housing                   104384.0
# 50084       Multifamily Housing                   154913.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 32                         Parking                          42000.0
# 100                        Parking                         150726.0
# 102                        Parking                          51537.0
# 238            Distribution Center                          32881.0
# 264      Supermarket/Grocery Store                          48520.0
# ...                            ...                              ...
# 49986                      Parking                          23084.0
# 50003                      Parking                           3765.0
# 50016                      Parking                         127633.0
# 50046                      Parking                          27261.0
# 50084                      Parking                         135000.0
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 32                   Retail Store                          4500.0
# 100                         Other                         15139.0
# 102                           NaN                             NaN
# 238                       Parking                         11850.0
# 264                       Parking                         29839.0
# ...                           ...                             ...
# 49986                         NaN                             NaN
# 50003                         NaN                             NaN
# 50016                         NaN                             NaN
# 50046                         NaN                             NaN
# 50084                         NaN                             NaN
#
# [107 rows x 18 columns]

# %% [markdown]
# ## Incohérences de classe 10<br/>355 cas, 11 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \lt 0$
# * $\Delta a_i \lt 0$
# * $\Delta a_o = 0$

# %%
class_10_members = _table[a_class[10]]
class_10_members_details = join_use_allocation(class_10_members, data)
print(class_10_members_details.shape[0])
display(class_10_members_details)
# Out:
# 355
#                       btype                 ptype       a    a_o     a_i  \
# id
# 18           NonResidential                 Hotel  315952  57600  258352
# 19           NonResidential                 Hotel   92190  25200   66990
# 22           NonResidential                 Other  103911      0  103911
# 23           NonResidential                 Hotel  416281  85000  331281
# 43                   Campus    Mixed Use Property  494835      0  494835
# ...                     ...                   ...     ...    ...     ...
# 50035        NonResidential                 Hotel  144614      0  144614
# 50061  Multifamily MR (5-9)  Mid-Rise Multifamily   91128      0   91128
# 50062        NonResidential                 Hotel  126823  41539   85284
# 50081        NonResidential           K-12 School   45000      0   45000
# 50101     Nonresidential WA            University   68072      0   68072
#
#            a_u  a_u_o    a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 18      353111  57600   295511   -37159            0       -37159
# 19       92590  25200    67390     -400            0         -400
# 22      130000      0   130000   -26089            0       -26089
# 23      433329  85000   348329   -17048            0       -17048
# 43     1856706      0  1856706 -1361871            0     -1361871
# ...        ...    ...      ...      ...          ...          ...
# 50035   159500      0   159500   -14886            0       -14886
# 50061    97468      0    97468    -6340            0        -6340
# 50062   129696  41539    88157    -2873            0        -2873
# 50081    45728      0    45728     -728            0         -728
# 50101    68916      0    68916     -844            0         -844
#
#                                ListOfAllPropertyUseTypes  \
# id
# 18                                        Hotel, Parking
# 19                                        Hotel, Parking
# 22     Fitness Center/Health Club/Gym, Office, Swimmi...
# 23                                        Hotel, Parking
# 43     Energy/Power Station, Laboratory, Manufacturin...
# ...                                                  ...
# 50035                                              Hotel
# 50061                                Multifamily Housing
# 50062                      Hotel, Parking, Swimming Pool
# 50081                               K-12 School, Parking
# 50101                                 College/University
#
#                LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 18                              Hotel                   295511.0
# 19                              Hotel                    67390.0
# 22     Fitness Center/Health Club/Gym                    90000.0
# 23                              Hotel                   348329.0
# 43                             Office                   757027.0
# ...                               ...                        ...
# 50035                           Hotel                   159500.0
# 50061             Multifamily Housing                    91128.0
# 50062                           Hotel                    88157.0
# 50081                     K-12 School                    45728.0
# 50101              College/University                    68916.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 18                         Parking                          57600.0
# 19                         Parking                          25200.0
# 22                          Office                          40000.0
# 23                         Parking                          85000.0
# 43                      Laboratory                         639931.0
# ...                            ...                              ...
# 50035                          NaN                              NaN
# 50061                 Retail Store                           6340.0
# 50062                      Parking                          41539.0
# 50081                      Parking                              0.0
# 50101                          NaN                              NaN
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 18                            NaN                             NaN
# 19                            NaN                             NaN
# 22                  Swimming Pool                             0.0
# 23                            NaN                             NaN
# 43     Non-Refrigerated Warehouse                        459748.0
# ...                           ...                             ...
# 50035                         NaN                             NaN
# 50061                         NaN                             NaN
# 50062               Swimming Pool                             0.0
# 50081                         NaN                             NaN
# 50101                         NaN                             NaN
#
# [355 rows x 18 columns]

# %% [markdown]
# ## Incohérences de classe 11<br/>67 cas, 2 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \lt 0$
# * $\Delta a_i \lt 0$
# * $\Delta a_o \gt 0$

# %%
class_11_members = _table[a_class[11]]
class_11_members_details = join_use_allocation(class_11_members, data)
print(class_11_members_details.shape[0])
display(class_11_members_details)
# Out:
# 67
#                       btype                  ptype       a     a_o     a_i  \
# id
# 16           NonResidential                  Hotel  333176   61161  272015
# 21       Nonresidential COS                  Other  412000   57000  355000
# 56           NonResidential                  Hotel  332210  205970  126240
# 63           NonResidential                  Hotel  994212  146694  847518
# 69           NonResidential                  Hotel  116300   28200   88100
# ...                     ...                    ...     ...     ...     ...
# 50057  Multifamily HR (10+)  High-Rise Multifamily  319481   41915  277566
# 50074  Multifamily MR (5-9)   Mid-Rise Multifamily   59653   14383   45270
# 50090  Multifamily MR (5-9)   Mid-Rise Multifamily   63825    4850   58975
# 50093  Multifamily MR (5-9)   Mid-Rise Multifamily   86045    8908   77137
# 50095  Multifamily MR (5-9)   Mid-Rise Multifamily  208136   58818  149318
#
#            a_u   a_u_o   a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 16      336640       0  336640    -3464        61161       -64625
# 21      414987   49000  365987    -2987         8000       -10987
# 56      348630       0  348630   -16420       205970      -222390
# 63     1111880  117668  994212  -117668        29026      -146694
# 69      116790       0  116790     -490        28200       -28690
# ...        ...     ...     ...      ...          ...          ...
# 50057   396398   35180  361218   -76917         6735       -83652
# 50074    60023   10664   49359     -370         3719        -4089
# 50090    71241       0   71241    -7416         4850       -12266
# 50093    87854    8126   79728    -1809          782        -2591
# 50095   212938   44717  168221    -4802        14101       -18903
#
#                                ListOfAllPropertyUseTypes  \
# id
# 16                                                 Hotel
# 21                         Data Center, Library, Parking
# 56                                                 Hotel
# 63                         Hotel, Parking, Swimming Pool
# 69                                                 Hotel
# ...                                                  ...
# 50057  Multifamily Housing, Office, Other - Lodging/R...
# 50074                       Multifamily Housing, Parking
# 50090                                Multifamily Housing
# 50093  Multifamily Housing, Other - Public Services, ...
# 50095                       Multifamily Housing, Parking
#
#       LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 16                     Hotel                   336640.0
# 21                   Library                   364913.0
# 56                     Hotel                   348630.0
# 63                     Hotel                   994212.0
# 69                     Hotel                    88490.0
# ...                      ...                        ...
# 50057    Multifamily Housing                   308680.0
# 50074    Multifamily Housing                    49359.0
# 50090    Multifamily Housing                    71241.0
# 50093    Multifamily Housing                    78359.0
# 50095    Multifamily Housing                   168221.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 16                             NaN                              NaN
# 21                         Parking                          49000.0
# 56                             NaN                              NaN
# 63                         Parking                         117668.0
# 69                         Parking                          28300.0
# ...                            ...                              ...
# 50057  Other - Lodging/Residential                          52538.0
# 50074                      Parking                          10664.0
# 50090                          NaN                              NaN
# 50093                      Parking                           8126.0
# 50095                      Parking                          44717.0
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 16                            NaN                             NaN
# 21                    Data Center                          1074.0
# 56                            NaN                             NaN
# 63                  Swimming Pool                             0.0
# 69                            NaN                             NaN
# ...                           ...                             ...
# 50057                     Parking                         35180.0
# 50074                         NaN                             NaN
# 50090                         NaN                             NaN
# 50093     Other - Public Services                          1369.0
# 50095                         NaN                             NaN
#
# [67 rows x 18 columns]

# %% [markdown]
# ## Incohérences de classe 12<br/>80 cas, 2 % des cas
#
# Ce sont  les cas où :
# * $\Delta a \lt 0$
# * $\Delta a_i \lt 0$
# * $\Delta a_o \lt 0$

# %%
class_12_members = _table[a_class[12]]
class_12_members_details = join_use_allocation(class_12_members, data)
print(class_12_members_details.shape[0])
display(class_12_members_details)
# Out:
# 80
#                       btype                 ptype        a     a_o      a_i  \
# id
# 8            NonResidential                 Hotel   175580   62000   113580
# 107          NonResidential          Large Office   571329       0   571329
# 147          NonResidential              Hospital   285333       0   285333
# 268          NonResidential              Hospital   597519       0   597519
# 276          NonResidential              Hospital  1158691       0  1158691
# ...                     ...                   ...      ...     ...      ...
# 50002        NonResidential                 Other    33648       0    33648
# 50054    Nonresidential COS          Large Office   536697  197659   339038
# 50086  Multifamily LR (1-4)  Low-Rise Multifamily    51095    2784    48311
# 50088  Multifamily LR (1-4)  Low-Rise Multifamily    41403       0    41403
# 50089  Multifamily LR (1-4)  Low-Rise Multifamily    25442     604    24838
#
#            a_u   a_u_o    a_u_i  a - a_u  a_o - a_u_o  a_i - a_u_i  \
# id
# 8       191454   68009   123445   -15874        -6009        -9865
# 107     935703  310699   625004  -364374      -310699       -53675
# 147     451526  148865   302661  -166193      -148865       -17328
# 268     650222   48607   601615   -52703       -48607        -4096
# 276    1737833  387651  1350182  -579142      -387651      -191491
# ...        ...     ...      ...      ...          ...          ...
# 50002   122600   83600    39000   -88952       -83600        -5352
# 50054   551329  202178   349151   -14632        -4519       -10113
# 50086    52115    2791    49324    -1020           -7        -1013
# 50088    46955    4941    42014    -5552        -4941         -611
# 50089    34164    5582    28582    -8722        -4978        -3744
#
#                                ListOfAllPropertyUseTypes  \
# id
# 8                          Hotel, Parking, Swimming Pool
# 107                               Office, Other, Parking
# 147       Hospital (General Medical & Surgical), Parking
# 268       Hospital (General Medical & Surgical), Parking
# 276       Hospital (General Medical & Surgical), Parking
# ...                                                  ...
# 50002                     Automobile Dealership, Parking
# 50054                      Office, Parking, Retail Store
# 50086                       Multifamily Housing, Parking
# 50088                       Multifamily Housing, Parking
# 50089  Multifamily Housing, Parking, Personal Service...
#
#                       LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 8                                      Hotel                   123445.0
# 107                                   Office                   598801.0
# 147    Hospital (General Medical & Surgical)                   302661.0
# 268    Hospital (General Medical & Surgical)                   601615.0
# 276    Hospital (General Medical & Surgical)                  1350182.0
# ...                                      ...                        ...
# 50002                                Parking                    83600.0
# 50054                                 Office                   342838.0
# 50086                    Multifamily Housing                    49324.0
# 50088                    Multifamily Housing                    42014.0
# 50089                    Multifamily Housing                    25052.0
#
#       SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 8                          Parking                          68009.0
# 107                        Parking                         310699.0
# 147                        Parking                         148865.0
# 268                        Parking                          48607.0
# 276                        Parking                         387651.0
# ...                            ...                              ...
# 50002        Automobile Dealership                          39000.0
# 50054                      Parking                         202178.0
# 50086                      Parking                           2791.0
# 50088                      Parking                           4941.0
# 50089                      Parking                           5582.0
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 8                   Swimming Pool                        0.000000
# 107                         Other                    26203.000000
# 147                           NaN                             NaN
# 268                           NaN                             NaN
# 276                           NaN                             NaN
# ...                           ...                             ...
# 50002                         NaN                             NaN
# 50054                Retail Store                     6313.200195
# 50086                         NaN                             NaN
# 50088                         NaN                             NaN
# 50089                  Restaurant                     3530.000000
#
# [80 rows x 18 columns]

# %% [markdown]
# # Etude de cas remarquables

# %% [markdown]
# ## Etiquetage des classes

# %%
import pandas as pd
def get_class_labels(table):
    s = pd.Series(index=table.index, name='class', dtype=int)
    for i, bi in enumerate(a_class):
        s[bi] = i
    return s.astype(int)

class_labels = get_class_labels(table)

# %% [markdown]
# ## Le cas n° 32

# %%
print('Class of case n° 32 :', class_labels.loc[32])
# Out:
# Class of case n° 32 : 9

# %% [markdown]
# Extraction des informations :

# %%
#from IPython.display import display, Math
from pepper_commons import bold, print_title, print_subtitle

def display_sample_info(id, data, table, class_labels):
    print_title(f"Sample n° {id}")
    sample = data.loc[id]
    sample_analysis = table.loc[id]
    sample_class = class_labels.loc[id]

    print_subtitle("Main areas (GFA)")
    display(Math("a = " + str(sample_analysis['a'])))
    display(Math("a_i = " + str(sample_analysis['a_i']) + " = p_i + \\overline{p_i}"))
    display(Math("a_o = " + str(sample_analysis['a_o']) + " = p_o + \\overline{p_o}"))
    display(Math("a_u = " + str(sample_analysis['a_u'])))
    display(Math("a_{u_i} = " + str(sample_analysis['a_u_i'])))
    display(Math("a_{u_o} = " + str(sample_analysis['a_u_o'])))
    
    print_subtitle("Areas diffs")
    display(Math("\Delta a = a - a_u = " + str(sample_analysis['a - a_u'])))
    display(Math("\Delta a_i = a_i - a_{u_i} = " + str(sample_analysis['a_i - a_u_i'])))
    display(Math("\Delta a_o = a_o - a_{u_o} = " + str(sample_analysis['a_o - a_u_o'])))

    print_subtitle("Details : areas by use")
    display(Math("a_\\text{1st} = a_\\text{"
        + sample.LargestPropertyUseType + "} = "
        + str(int(sample.LargestPropertyUseTypeGFA))))
    display(Math("a_\\text{2nd} = a_\\text{"
        + sample.SecondLargestPropertyUseType + "} = "
        + str(int(sample.SecondLargestPropertyUseTypeGFA))))
    display(Math("a_\\text{3rd} = a_\\text{"
        + sample.ThirdLargestPropertyUseType + "} = "
        + str(int(sample.ThirdLargestPropertyUseTypeGFA))))


display_sample_info(32, _data, _table, class_labels)
# Out:
# SAMPLE N° 32
#
# Main areas (GFA)
# $\displaystyle a = 158676$
# $\displaystyle a_i = 128375 = p_i + \overline{p_i}$
# $\displaystyle a_o = 30301 = p_o + \overline{p_o}$
# $\displaystyle a_u = 159176$
# $\displaystyle a_{u_i} = 117176$
# $\displaystyle a_{u_o} = 42000$
# Areas diffs
# $\displaystyle \Delta a = a - a_u = -500$
# $\displaystyle \Delta a_i = a_i - a_{u_i} = 11199$
# $\displaystyle \Delta a_o = a_o - a_{u_o} = -11699$
# Details : areas by use
# $\displaystyle a_\text{1st} = a_\text{Hotel} = 112676$
# $\displaystyle a_\text{2nd} = a_\text{Parking} = 42000$
# $\displaystyle a_\text{3rd} = a_\text{Retail Store} = 4500$

# %%
display(_data.loc[32])
# Out:
# BuildingType                                                    NonResidential
# PrimaryPropertyType                                                      Hotel
# PropertyName                                                   Homewood Suites
# Address                                                           1011 Pike ST
# ZipCode                                                                98101.0
# TaxParcelIdentificationNumber                                       0660001832
# CouncilDistrictCode                                                          7
# Neighborhood                                                              EAST
# Latitude                                                              47.61301
# Longitude                                                           -122.32929
# YearBuilt                                                                 1991
# NumberofBuildings                                                          1.0
# NumberofFloors                                                               8
# PropertyGFATotal                                                        158676
# PropertyGFAParking                                                       30301
# PropertyGFABuilding(s)                                                  128375
# ListOfAllPropertyUseTypes          Hotel, Parking, Retail Store, Swimming Pool
# LargestPropertyUseType                                                   Hotel
# LargestPropertyUseTypeGFA                                             112676.0
# SecondLargestPropertyUseType                                           Parking
# SecondLargestPropertyUseTypeGFA                                        42000.0
# ThirdLargestPropertyUseType                                       Retail Store
# ThirdLargestPropertyUseTypeGFA                                          4500.0
# YearsENERGYSTARCertified                                                   NaN
# ENERGYSTARScore                                                            NaN
# SiteEUI(kBtu/sf)                                                          45.5
# SiteEUIWN(kBtu/sf)                                                   46.299999
# SourceEUI(kBtu/sf)                                                        58.0
# SourceEUIWN(kBtu/sf)                                                 58.799999
# SiteEnergyUse(kBtu)                                                  5328051.5
# SiteEnergyUseWN(kBtu)                                                5424942.0
# SteamUse(kBtu)                                                             0.0
# Electricity(kWh)                                                      167733.5
# Electricity(kBtu)                                                     572307.0
# NaturalGas(therms)                                                 47557.44922
# NaturalGas(kBtu)                                                     4755745.0
# TotalGHGEmissions                                                       256.57
# GHGEmissionsIntensity                                                     1.62
# Name: 32, dtype: object

# %% [markdown]
# # Export GSheet
#
# Pourquoi exporter vu que la même opération est facile à réaliser directement en GSheet ?
#
# 3 feuilles : version brute, version corrigée, diff : modfications correctives rendues visibles.
#
# 1/ On commence doucement : production et export du tableau avec les détails muni d'une colonne de classe.
# 2/ visualisation des scatters pour chacune des classes (ça, je l'insère au-dessus), en version brute et en version corrigée
# 3/ ...

# %% [markdown]
# ### Tableau avec détail et classes
#
# Rappel :
# |Classe|$\Delta s$|$\Delta s_i$|$\Delta s_e$|#cas|Commentaire/correction|
#
# <mark>... le faire produire par une fonction</mark>

# %%
def add_class_id(table):
    classes_list = [
        class_1, class_2, class_3, class_4, class_5, class_6, class_7,
        class_8, class_9, class_10, class_11, class_12, class_13]
    table['class_id'] = 0
    for i, c in enumerate(classes_list):
        table.loc[c, 'class_id'] = i + 1

# %%
exported = _table.copy()
add_class_id(exported)
exported = join_use_allocation(exported, data)
display(exported)
# Out:
#                     btype               ptype       s      se      si     s_u  \
# id
# 1          NonResidential               Hotel   88434       0   88434   88434
# 2          NonResidential               Hotel  103566   15064   88502  103566
# 3          NonResidential               Hotel  956110  196718  759392  756493
# 5          NonResidential               Hotel   61320       0   61320   61320
# 8          NonResidential               Hotel  175580   62000  113580  191454
# ...                   ...                 ...     ...     ...     ...     ...
# 50221  Nonresidential COS               Other   18261       0   18261   18261
# 50223  Nonresidential COS               Other   16000       0   16000   16000
# 50224  Nonresidential COS               Other   13157       0   13157   13157
# 50225  Nonresidential COS  Mixed Use Property   14101       0   14101   13586
# 50226  Nonresidential COS  Mixed Use Property   18258       0   18258   17379
#
#         se_u    si_u  s - s_u  se - se_u  si - si_u  class_id  \
# id
# 1          0   88434        0          0          0         1
# 2      15064   88502        0          0          0         1
# 3          0  756493   199617     196718       2899         6
# 5          0   61320        0          0          0         1
# 8      68009  123445   -15874      -6009      -9865        13
# ...      ...     ...      ...        ...        ...       ...
# 50221      0   18261        0          0          0         1
# 50223      0   16000        0          0          0         1
# 50224      0   13157        0          0          0         1
# 50225      0   13586      515          0        515         5
# 50226      0   17379      879          0        879         5
#
#                                ListOfAllPropertyUseTypes  \
# id
# 1                                                  Hotel
# 2                             Hotel, Parking, Restaurant
# 3                                                  Hotel
# 5                                                  Hotel
# 8                          Hotel, Parking, Swimming Pool
# ...                                                  ...
# 50221                                 Other - Recreation
# 50223                                 Other - Recreation
# 50224  Fitness Center/Health Club/Gym, Other - Recrea...
# 50225  Fitness Center/Health Club/Gym, Food Service, ...
# 50226  Fitness Center/Health Club/Gym, Food Service, ...
#
#       LargestPropertyUseType  LargestPropertyUseTypeGFA  \
# id
# 1                      Hotel                    88434.0
# 2                      Hotel                    83880.0
# 3                      Hotel                   756493.0
# 5                      Hotel                    61320.0
# 8                      Hotel                   123445.0
# ...                      ...                        ...
# 50221     Other - Recreation                    18261.0
# 50223     Other - Recreation                    16000.0
# 50224     Other - Recreation                     7583.0
# 50225     Other - Recreation                     6601.0
# 50226     Other - Recreation                     8271.0
#
#          SecondLargestPropertyUseType  SecondLargestPropertyUseTypeGFA  \
# id
# 1                                 NaN                              NaN
# 2                             Parking                          15064.0
# 3                                 NaN                              NaN
# 5                                 NaN                              NaN
# 8                             Parking                          68009.0
# ...                               ...                              ...
# 50221                             NaN                              NaN
# 50223                             NaN                              NaN
# 50224  Fitness Center/Health Club/Gym                           5574.0
# 50225  Fitness Center/Health Club/Gym                           6501.0
# 50226  Fitness Center/Health Club/Gym                           8000.0
#
#       ThirdLargestPropertyUseType  ThirdLargestPropertyUseTypeGFA
# id
# 1                             NaN                             NaN
# 2                      Restaurant                          4622.0
# 3                             NaN                             NaN
# 5                             NaN                             NaN
# 8                   Swimming Pool                             0.0
# ...                           ...                             ...
# 50221                         NaN                             NaN
# 50223                         NaN                             NaN
# 50224               Swimming Pool                             0.0
# 50225          Pre-school/Daycare                           484.0
# 50226          Pre-school/Daycare                          1108.0
#
# [3211 rows x 19 columns]

# %%
exported.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3211 entries, 1 to 50226
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   btype                            3211 non-null   object
#  1   ptype                            3211 non-null   object
#  2   s                                3211 non-null   int64
#  3   se                               3211 non-null   int64
#  4   si                               3211 non-null   int64
#  5   s_u                              3211 non-null   int32
#  6   se_u                             3211 non-null   int32
#  7   si_u                             3211 non-null   int32
#  8   s - s_u                          3211 non-null   int32
#  9   se - se_u                        3211 non-null   int32
#  10  si - si_u                        3211 non-null   int32
#  11  class_id                         3211 non-null   int64
#  12  ListOfAllPropertyUseTypes        3207 non-null   object
#  13  LargestPropertyUseType           3196 non-null   object
#  14  LargestPropertyUseTypeGFA        3196 non-null   float64
#  15  SecondLargestPropertyUseType     1647 non-null   object
#  16  SecondLargestPropertyUseTypeGFA  1647 non-null   float64
#  17  ThirdLargestPropertyUseType      583 non-null    object
#  18  ThirdLargestPropertyUseTypeGFA   583 non-null    float64
# dtypes: float64(3), int32(6), int64(4), object(6)
# memory usage: 555.5+ KB

# %%
from gspread_pandas import Spread
spread = Spread('1gtTOd-taN9aY8sg4PGY456E2AlsMxi2W_-7kZaCSYlA')    # target GSheet TODO : externaliser, spécif. user
as_fr_FR = [c for c in exported.columns if exported[c].dtype == 'float64']
data_to_gsheet(exported, spread, 'gross_areas', as_code=None, as_fr_FR=as_fr_FR)
