# %%
import os
import jpy_commons as jpy
import jpy_class_selection as sel

# %%
data = jpy._test_data
display(data)
# Out:
#       OSEBuildingID  DataYear        BuildingType PrimaryPropertyType  \
# 0                 1      2016      NonResidential               Hotel
# 1                 2      2016      NonResidential               Hotel
# 2                 3      2016      NonResidential               Hotel
# 3                 5      2016      NonResidential               Hotel
# 4                 8      2016      NonResidential               Hotel
# ...             ...       ...                 ...                 ...
# 3371          50222      2016  Nonresidential COS              Office
# 3372          50223      2016  Nonresidential COS               Other
# 3373          50224      2016  Nonresidential COS               Other
# 3374          50225      2016  Nonresidential COS  Mixed Use Property
# 3375          50226      2016  Nonresidential COS  Mixed Use Property
#
#                              PropertyName           Address     City State  \
# ...

# %%
sel.test_normalize_operands(data)
# Out:
# test 1 : one bool array
# type : <class 'pandas.core.series.Series'>
# size : 3376
# dtype : <class 'numpy.bool_'>
# single operand
#
# test 2 : 2 bool arrays
# type : <class 'list'>
# size : 2
# dtype : <class 'pandas.core.series.Series'>
# vector of operands
#
# test 3 : one index
# type : <class 'pandas.core.indexes.numeric.Int64Index'>
# size : 1460
# dtype : <class 'numpy.int64'>
# single operand
#
# test 4 : 2 indexes
# type : <class 'list'>
# size : 2
# dtype : <class 'pandas.core.indexes.numeric.Int64Index'>
# vector of operands
#
# test 5 : one indices
# type : <class 'numpy.ndarray'>
# size : 1460
# dtype : <class 'numpy.int32'>
# single operand
#
# test 6 : 2 indices
# type : <class 'list'>
# size : 2
# dtype : <class 'numpy.ndarray'>
# vector of operands

# %%
sel.test_eval_after_normalize(data)
# Out:
# type : <class 'list'>
# size : 2
# dtype : <class 'pandas.core.series.Series'>
# vector of operands
# (2, 3376)
# (<class 'list'>, <class 'pandas.core.series.Series'>)
# index size : 3376
#       OSEBuildingID  DataYear    BuildingType          PrimaryPropertyType  \
# 32               38      2016  NonResidential  Small- and Mid-Sized Office
# 39               52      2016  NonResidential  Small- and Mid-Sized Office
# 40               53      2016  NonResidential  Small- and Mid-Sized Office
# 44               57      2016  NonResidential                 Large Office
# 46               59      2016  NonResidential  Small- and Mid-Sized Office
# ...             ...       ...             ...                          ...
# 3312          50026      2016  NonResidential  Small- and Mid-Sized Office
# 3317          50031      2016  NonResidential                 Large Office
# 3320          50037      2016  NonResidential                 Large Office
# ...

# %%
sel.test_display_selector()
# Out:
# &
#   assert[ComplianceStatus, Compliant]
#   |
#     assert[BuildingType, Multifamily]
#     assert[PrimaryPropertyType, Multifamily]
#   ~
#     |
#       assert[BuildingType, Campus]
#       assert[BuildingType, NonResidential]

# %%
sel.test_instance_selector(data)
# Out:
#       OSEBuildingID  DataYear          BuildingType   PrimaryPropertyType  \
# 9                13      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 165             265      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 173             280      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 188             296      2016  Multifamily LR (1-4)  Low-Rise Multifamily
# 189             297      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# ...             ...       ...                   ...                   ...
# 3353          50090      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3354          50092      2016  Multifamily MR (5-9)        Residence Hall
# 3355          50093      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3357          50095      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3358          50098      2016  Multifamily LR (1-4)  Low-Rise Multifamily
#
#                       PropertyName               Address     City State  \
# ...

# %%
# compositions simple
sel.test_compound_instance_selector(data)
# Out:
#       OSEBuildingID  DataYear          BuildingType   PrimaryPropertyType  \
# 9                13      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 22               28      2016     SPS-District K-12           K-12 School
# 28               34      2016     SPS-District K-12           K-12 School
# 30               36      2016     SPS-District K-12           K-12 School
# 31               37      2016     SPS-District K-12           K-12 School
# ...             ...       ...                   ...                   ...
# 3353          50090      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3354          50092      2016  Multifamily MR (5-9)        Residence Hall
# 3355          50093      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3357          50095      2016  Multifamily MR (5-9)  Mid-Rise Multifamily
# 3358          50098      2016  Multifamily LR (1-4)  Low-Rise Multifamily
#
#                  PropertyName               Address     City State  ZipCode  \
# ...
